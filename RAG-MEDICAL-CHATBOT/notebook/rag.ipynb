# %%
# %pip install uv
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.8/21.8 MB 33.6 MB/s  0:00:00 eta 0:00:01
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: /opt/homebrew/opt/python@3.11/bin/python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
! uv pip install langchain openai tiktoken rapidocr-onnxruntime python-dotenv langchain-community
# Out:
# Using Python 3.12.2 environment at: /Users/neelamahlawat/Documents/AI-coding/Generative-AI-Projects/.venv
# Resolved 66 packages in 582ms
# ⠙ Preparing packages... (0/65)
# ⠙ Preparing packages... (0/65)------------------     0 B/59.54 KiB
# ⠙ Preparing packages... (0/65)------------------ 14.79 KiB/59.54 KiB
# ⠙ Preparing packages... (0/65)------------------ 14.79 KiB/59.54 KiB
# typing-extensions    ------------------------------     0 B/43.57 KiB
# ⠙ Preparing packages... (0/65)------------------ 14.79 KiB/59.54 KiB
# typing-extensions    ------------------------------ 14.79 KiB/43.57 KiB
# ⠙ Preparing packages... (0/65)------------------ 14.79 KiB/59.54 KiB
# typing-extensions    ------------------------------ 14.79 KiB/43.57 KiB
# ⠙ Preparing packages... (0/65)------------------ 14.79 KiB/59.54 KiB
# typing-extensions    ------------------------------ 14.79 KiB/43.57 KiB
# ⠙ Preparing packages... (0/65)------------------ 14.79 KiB/59.54 KiB
# ...
